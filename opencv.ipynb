# %%
import tensorflow as tf

# %%
import keras

# %%
import cv2

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

# %%
img_width, img_hight = 200, 200

# %%
model = load_model('dlmodel.h5')

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
cap = cv2.VideoCapture(0)
 
img_count_full = 0

font = cv2.FONT_HERSHEY_SIMPLEX 
# org 
org = (1, 1)
class_lable=' '      
# fontScale 
fontScale = 1 #0.5
# Blue color in BGR 
color = (255, 0, 0) 
# Line thickness of 2 px 
thickness = 2 #1

# %%
while True:
    img_count_full += 1
     
    #read image from webcam
    responce, color_img = cap.read()
    #color_img = cv2.imread('sandeep.jpg')
     
    #if respoce False the break the loop
    if responce == False:
        break    
     
    # Convert to grayscale
    gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
     
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray_img, 1.1, 6) 
     
    #take face then predict class mask or not mask then draw recrangle and text then display image
    img_count = 0
    for (x, y, w, h) in faces:
        org = (x-10,y-10)
        img_count +=1 
        color_face = color_img[y:y+h,x:x+w] # color face
        cv2.imwrite('faces/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('faces/input/%d%dface.jpg'%(img_count_full,img_count), target_size=(img_width,img_hight))
         
        img = img_to_array(img)/255
        img = np.expand_dims(img,axis=0)
        pred_prob = model.predict(img)
        #print(pred_prob[0][0].round(2))
        pred=np.argmax(pred_prob)
             
        if pred==0:
            print("User with mask - predic = ",pred_prob[0][0])
            class_lable = "Mask"
            color = (255, 0, 0)
            cv2.imwrite('faces/with_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                  
        else:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 255, 0)
            cv2.imwrite('faces/without_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                 
        cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 0, 255), 3)
        # Using cv2.putText() method 
        cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA) 
     
    # display image
    cv2.imshow('LIVE face mask detection', color_img)
     
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
 
# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# user not wearing mask - prob =  0.77703595
# user not wearing mask - prob =  0.7930425
# user not wearing mask - prob =  0.77914554
# user not wearing mask - prob =  0.7871066
# user not wearing mask - prob =  0.77719957
# user not wearing mask - prob =  0.78685313
# user not wearing mask - prob =  0.79682964
# user not wearing mask - prob =  0.78826684
# user not wearing mask - prob =  0.78543276
# user not wearing mask - prob =  0.7964343
# user not wearing mask - prob =  0.7943247
# user not wearing mask - prob =  0.7507562
# user not wearing mask - prob =  0.7328592
# user not wearing mask - prob =  0.7417386
# user not wearing mask - prob =  0.7367048
# user not wearing mask - prob =  0.7659055
# user not wearing mask - prob =  0.7968913
# user not wearing mask - prob =  0.7732917
# user not wearing mask - prob =  0.80631626
# user not wearing mask - prob =  0.8114933
# user not wearing mask - prob =  0.8058998
# user not wearing mask - prob =  0.8040867
# user not wearing mask - prob =  0.742848
# user not wearing mask - prob =  0.7959826
# user not wearing mask - prob =  0.7959826
# user not wearing mask - prob =  0.80580753
# user not wearing mask - prob =  0.80072963
# user not wearing mask - prob =  0.7940787
# user not wearing mask - prob =  0.808156
# user not wearing mask - prob =  0.7562869
# user not wearing mask - prob =  0.783722
# user not wearing mask - prob =  0.75483066
# user not wearing mask - prob =  0.7871053
# user not wearing mask - prob =  0.80514914
# user not wearing mask - prob =  0.8139879
# user not wearing mask - prob =  0.7785796
# user not wearing mask - prob =  0.7951511
# user not wearing mask - prob =  0.7951511
# user not wearing mask - prob =  0.77001363
# user not wearing mask - prob =  0.77005434
# user not wearing mask - prob =  0.780581
# user not wearing mask - prob =  0.80845124
# user not wearing mask - prob =  0.80964047
# user not wearing mask - prob =  0.7910737
# user not wearing mask - prob =  0.7673962
# user not wearing mask - prob =  0.7673962
# user not wearing mask - prob =  0.7725612
# user not wearing mask - prob =  0.7684022
# user not wearing mask - prob =  0.77338487
# user not wearing mask - prob =  0.784259
# user not wearing mask - prob =  0.7723518
# user not wearing mask - prob =  0.78764635
# user not wearing mask - prob =  0.7691579
# user not wearing mask - prob =  0.7871736
# user not wearing mask - prob =  0.78332955
# user not wearing mask - prob =  0.78332955
# user not wearing mask - prob =  0.77559894
# user not wearing mask - prob =  0.7698827
# user not wearing mask - prob =  0.7851691
# user not wearing mask - prob =  0.7926546
# user not wearing mask - prob =  0.77293885
# user not wearing mask - prob =  0.7886907
# user not wearing mask - prob =  0.7886907
# user not wearing mask - prob =  0.7527773
# user not wearing mask - prob =  0.75107515
# user not wearing mask - prob =  0.77016366
# user not wearing mask - prob =  0.75391936
# user not wearing mask - prob =  0.7891239
# user not wearing mask - prob =  0.78026
# user not wearing mask - prob =  0.78026
# user not wearing mask - prob =  0.7816491
# user not wearing mask - prob =  0.7815951
# user not wearing mask - prob =  0.79075277
# user not wearing mask - prob =  0.8089261
# user not wearing mask - prob =  0.7884469
# user not wearing mask - prob =  0.78660655
# user not wearing mask - prob =  0.7626368
# user not wearing mask - prob =  0.7626368
# user not wearing mask - prob =  0.7924691
# user not wearing mask - prob =  0.75628424
# user not wearing mask - prob =  0.7232549
# user not wearing mask - prob =  0.8339727
# user not wearing mask - prob =  0.7746804
# user not wearing mask - prob =  0.7746804
# user not wearing mask - prob =  0.76399326
# user not wearing mask - prob =  0.76399326
# user not wearing mask - prob =  0.78027964
# user not wearing mask - prob =  0.77180904
# user not wearing mask - prob =  0.76520264
# user not wearing mask - prob =  0.7542433
# user not wearing mask - prob =  0.72361404
# user not wearing mask - prob =  0.7701348
# user not wearing mask - prob =  0.7701348
# user not wearing mask - prob =  0.73820037
# user not wearing mask - prob =  0.5481111
# user not wearing mask - prob =  0.8841918
# User with mask - predic =  0.9999728
# User with mask - predic =  0.9999728
# User with mask - predic =  0.9999893
# User with mask - predic =  0.9999893
# User with mask - predic =  0.99999654
# User with mask - predic =  0.9999577
# User with mask - predic =  0.9999577
# User with mask - predic =  0.9999914
# User with mask - predic =  0.9999821
# User with mask - predic =  0.9999821
# User with mask - predic =  0.9999747
# User with mask - predic =  0.99998295
# User with mask - predic =  0.9999752
# User with mask - predic =  0.9999726
# User with mask - predic =  0.9999726
